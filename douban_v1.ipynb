# %% [markdown]
# <a href="https://colab.research.google.com/github/RecoHut-Datasets/douban/blob/v1/douban_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import pandas as pd

# %%
df_list = [x for x in os.listdir('.') if x.endswith('.csv')]
df_list
# Out:
# ['all_item.csv',
#  'movie_item.csv',
#  'all_item_token.csv',
#  'all_users.csv',
#  'music_item.csv',
#  'all_rate.csv',
#  'book_item.csv']

# %%
for df_path in df_list:
    display(pd.read_csv(df_path, nrows=5))
# Out:
#    douban_id  douban_score  douban_votes  type  item_id
# 0   34443563           5.7          17.0     0        0
# 1   33440284           8.1         566.0     0        1
# 2   33420597           9.1          97.0     0        2
# 3   33429123           0.0           0.0     0        3
# 4   33384518           7.2         435.0     0        4
#    item_id  regions  genres  ...  movie_douban_score  movie_douban_votes  type
# 0   253526        0       0  ...                   0                   0     2
# 1   253527        1       1  ...                   0                   0     2
# 2   253528        2       2  ...                   0                   0     2
# 3   253529        3       3  ...                   0                   0     2
# 4   253530        4       4  ...                   0                   0     2
#
# [5 rows x 10 columns]
#    douban_id  douban_score  douban_votes  type  item_id
# 0   34443563             6             1     0        0
# ...

# %%
for df_path in df_list:
    display(pd.read_csv(df_path).info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303825 entries, 0 to 303824
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   douban_id     303825 non-null  int64
#  1   douban_score  303825 non-null  float64
#  2   douban_votes  303825 non-null  float64
#  3   type          303825 non-null  int64
#  4   item_id       303825 non-null  int64
# dtypes: float64(2), int64(3)
# memory usage: 11.6 MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50299 entries, 0 to 50298
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   item_id             50299 non-null  int64
#  1   regions             50299 non-null  int64
#  2   genres              50299 non-null  int64
#  3   languages           50299 non-null  int64
#  4   directors           50299 non-null  int64
#  5   year                50299 non-null  int64
# ...
